# %% [markdown]
# # Link Prediction

# %% [markdown]
# ## Preparation

# %%
# %env NX_CUGRAPH_AUTOCONFIG=True
# Out:
# env: NX_CUGRAPH_AUTOCONFIG=True

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding
# %pip install igraph networkit pandas matplotlib seaborn networkx numpy scikit-learn tqdm ipywidgets
# Out:
# Requirement already satisfied: igraph in d:\academic\projects\pd\.venv\lib\site-packages (0.11.8)
# Requirement already satisfied: networkit in d:\academic\projects\pd\.venv\lib\site-packages (11.1)
# Requirement already satisfied: pandas in d:\academic\projects\pd\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in d:\academic\projects\pd\.venv\lib\site-packages (3.10.1)
# Requirement already satisfied: seaborn in d:\academic\projects\pd\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: networkx in d:\academic\projects\pd\.venv\lib\site-packages (3.3)
# Requirement already satisfied: numpy in d:\academic\projects\pd\.venv\lib\site-packages (2.2.4)
# Requirement already satisfied: scikit-learn in d:\academic\projects\pd\.venv\lib\site-packages (1.6.1)
# Requirement already satisfied: tqdm in d:\academic\projects\pd\.venv\lib\site-packages (4.67.1)
# Requirement already satisfied: ipywidgets in d:\academic\projects\pd\.venv\lib\site-packages (8.1.5)
# Requirement already satisfied: texttable>=1.6.2 in d:\academic\projects\pd\.venv\lib\site-packages (from igraph) (1.7.0)
# Requirement already satisfied: scipy in d:\academic\projects\pd\.venv\lib\site-packages (from networkit) (1.15.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\academic\projects\pd\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\academic\projects\pd\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\academic\projects\pd\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\academic\projects\pd\.venv\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in d:\academic\projects\pd\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\academic\projects\pd\.venv\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\academic\projects\pd\.venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in d:\academic\projects\pd\.venv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in d:\academic\projects\pd\.venv\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\academic\projects\pd\.venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: joblib>=1.2.0 in d:\academic\projects\pd\.venv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\academic\projects\pd\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: colorama in d:\academic\projects\pd\.venv\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: comm>=0.1.3 in d:\academic\projects\pd\.venv\lib\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in d:\academic\projects\pd\.venv\lib\site-packages (from ipywidgets) (9.0.2)
# Requirement already satisfied: traitlets>=4.3.1 in d:\academic\projects\pd\.venv\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in d:\academic\projects\pd\.venv\lib\site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in d:\academic\projects\pd\.venv\lib\site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: decorator in d:\academic\projects\pd\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in d:\academic\projects\pd\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\academic\projects\pd\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in d:\academic\projects\pd\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in d:\academic\projects\pd\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in d:\academic\projects\pd\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack_data in d:\academic\projects\pd\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in d:\academic\projects\pd\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.13.0)
# Requirement already satisfied: six>=1.5 in d:\academic\projects\pd\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\academic\projects\pd\.venv\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in d:\academic\projects\pd\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in d:\academic\projects\pd\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in d:\academic\projects\pd\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in d:\academic\projects\pd\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip uninstall torch pykeen
# %pip install torch --index-url https://download.pytorch.org/whl/cu126
# %pip install pykeen
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu126
# Requirement already satisfied: torch in d:\academic\projects\pd\.venv\lib\site-packages (2.6.0+cu126)
# Requirement already satisfied: filelock in d:\academic\projects\pd\.venv\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\academic\projects\pd\.venv\lib\site-packages (from torch) (4.13.0)
# Requirement already satisfied: networkx in d:\academic\projects\pd\.venv\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in d:\academic\projects\pd\.venv\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in d:\academic\projects\pd\.venv\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in d:\academic\projects\pd\.venv\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\academic\projects\pd\.venv\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\academic\projects\pd\.venv\lib\site-packages (from jinja2->torch) (2.1.5)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pykeen in d:\academic\projects\pd\.venv\lib\site-packages (1.11.0)
# Requirement already satisfied: dataclasses-json in d:\academic\projects\pd\.venv\lib\site-packages (from pykeen) (0.6.7)
# Requirement already satisfied: numpy in d:\academic\projects\pd\.venv\lib\site-packages (from pykeen) (2.2.4)
# Requirement already satisfied: scipy>=1.7.0 in d:\academic\projects\pd\.venv\lib\site-packages (from pykeen) (1.15.2)
# Requirement already satisfied: click in d:\academic\projects\pd\.venv\lib\site-packages (from pykeen) (8.1.8)
# Requirement already satisfied: click-default-group in d:\academic\projects\pd\.venv\lib\site-packages (from pykeen) (1.2.4)
# Requirement already satisfied: scikit-learn in d:\academic\projects\pd\.venv\lib\site-packages (from pykeen) (1.6.1)
# Requirement already satisfied: torch>=2.0 in d:\academic\projects\pd\.venv\lib\site-packages (from pykeen) (2.6.0+cu126)
# Requirement already satisfied: tqdm in d:\academic\projects\pd\.venv\lib\site-packages (from pykeen) (4.67.1)
# Requirement already satisfied: requests in d:\academic\projects\pd\.venv\lib\site-packages (from pykeen) (2.32.3)
# Requirement already satisfied: optuna>=2.0.0 in d:\academic\projects\pd\.venv\lib\site-packages (from pykeen) (4.2.1)
# Requirement already satisfied: pandas>=1.0.0 in d:\academic\projects\pd\.venv\lib\site-packages (from pykeen) (2.2.3)
# Requirement already satisfied: tabulate in d:\academic\projects\pd\.venv\lib\site-packages (from pykeen) (0.9.0)
# Requirement already satisfied: more-click in d:\academic\projects\pd\.venv\lib\site-packages (from pykeen) (0.1.2)
# Requirement already satisfied: more-itertools in d:\academic\projects\pd\.venv\lib\site-packages (from pykeen) (10.6.0)
# Requirement already satisfied: pystow>=0.4.3 in d:\academic\projects\pd\.venv\lib\site-packages (from pykeen) (0.7.0)
# Requirement already satisfied: docdata in d:\academic\projects\pd\.venv\lib\site-packages (from pykeen) (0.0.4)
# Requirement already satisfied: class-resolver>=0.5.1 in d:\academic\projects\pd\.venv\lib\site-packages (from pykeen) (0.5.4)
# Requirement already satisfied: pyyaml in d:\academic\projects\pd\.venv\lib\site-packages (from pykeen) (6.0.2)
# Requirement already satisfied: torch-max-mem>=0.1.1 in d:\academic\projects\pd\.venv\lib\site-packages (from pykeen) (0.1.3)
# Requirement already satisfied: torch-ppr>=0.0.7 in d:\academic\projects\pd\.venv\lib\site-packages (from pykeen) (0.0.8)
# Requirement already satisfied: typing-extensions in d:\academic\projects\pd\.venv\lib\site-packages (from pykeen) (4.13.0)
# Requirement already satisfied: alembic>=1.5.0 in d:\academic\projects\pd\.venv\lib\site-packages (from optuna>=2.0.0->pykeen) (1.15.2)
# Requirement already satisfied: colorlog in d:\academic\projects\pd\.venv\lib\site-packages (from optuna>=2.0.0->pykeen) (6.9.0)
# Requirement already satisfied: packaging>=20.0 in d:\academic\projects\pd\.venv\lib\site-packages (from optuna>=2.0.0->pykeen) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in d:\academic\projects\pd\.venv\lib\site-packages (from optuna>=2.0.0->pykeen) (2.0.40)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\academic\projects\pd\.venv\lib\site-packages (from pandas>=1.0.0->pykeen) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\academic\projects\pd\.venv\lib\site-packages (from pandas>=1.0.0->pykeen) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\academic\projects\pd\.venv\lib\site-packages (from pandas>=1.0.0->pykeen) (2025.2)
# Requirement already satisfied: filelock in d:\academic\projects\pd\.venv\lib\site-packages (from torch>=2.0->pykeen) (3.13.1)
# Requirement already satisfied: networkx in d:\academic\projects\pd\.venv\lib\site-packages (from torch>=2.0->pykeen) (3.3)
# Requirement already satisfied: jinja2 in d:\academic\projects\pd\.venv\lib\site-packages (from torch>=2.0->pykeen) (3.1.4)
# Requirement already satisfied: fsspec in d:\academic\projects\pd\.venv\lib\site-packages (from torch>=2.0->pykeen) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in d:\academic\projects\pd\.venv\lib\site-packages (from torch>=2.0->pykeen) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\academic\projects\pd\.venv\lib\site-packages (from sympy==1.13.1->torch>=2.0->pykeen) (1.3.0)
# Requirement already satisfied: colorama in d:\academic\projects\pd\.venv\lib\site-packages (from click->pykeen) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in d:\academic\projects\pd\.venv\lib\site-packages (from dataclasses-json->pykeen) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in d:\academic\projects\pd\.venv\lib\site-packages (from dataclasses-json->pykeen) (0.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\academic\projects\pd\.venv\lib\site-packages (from requests->pykeen) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\academic\projects\pd\.venv\lib\site-packages (from requests->pykeen) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\academic\projects\pd\.venv\lib\site-packages (from requests->pykeen) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\academic\projects\pd\.venv\lib\site-packages (from requests->pykeen) (2025.1.31)
# Requirement already satisfied: joblib>=1.2.0 in d:\academic\projects\pd\.venv\lib\site-packages (from scikit-learn->pykeen) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\academic\projects\pd\.venv\lib\site-packages (from scikit-learn->pykeen) (3.6.0)
# Requirement already satisfied: Mako in d:\academic\projects\pd\.venv\lib\site-packages (from alembic>=1.5.0->optuna>=2.0.0->pykeen) (1.3.9)
# Requirement already satisfied: six>=1.5 in d:\academic\projects\pd\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->pykeen) (1.17.0)
# Requirement already satisfied: greenlet>=1 in d:\academic\projects\pd\.venv\lib\site-packages (from sqlalchemy>=1.4.2->optuna>=2.0.0->pykeen) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in d:\academic\projects\pd\.venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->pykeen) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\academic\projects\pd\.venv\lib\site-packages (from jinja2->torch>=2.0->pykeen) (2.1.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import networkx as nx
import pickle
import random
import igraph as ig
import networkit as nk

from itertools import combinations
from sklearn.metrics import roc_auc_score, average_precision_score, f1_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import mutual_info_classif
from tqdm import tqdm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
# Out:
# 			<script type="text/javascript">
# 			<!--
#
# 			{
# 				var element = document.getElementById('NetworKit_script');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('script');
# 				element.type = 'text/javascript';
# 				element.innerHTML = 'function NetworKit_pageEmbed(id) { var i, j; var elements; elements = document.getElementById(id).getElementsByClassName("Plot"); for (i=0; i<elements.length; i++) { elements[i].id = id + "_Plot_" + i; var data = elements[i].getAttribute("data-image").split("|"); elements[i].removeAttribute("data-image"); var content = "<div class=\\"Image\\" id=\\"" + elements[i].id + "_Image\\" />"; elements[i].innerHTML = content; elements[i].setAttribute("data-image-index", 0); elements[i].setAttribute("data-image-length", data.length); for (j=0; j<data.length; j++) { elements[i].setAttribute("data-image-" + j, data[j]); } NetworKit_plotUpdate(elements[i]); elements[i].onclick = function (e) { NetworKit_overlayShow((e.target) ? e.target : e.srcElement); } } elements = document.getElementById(id).getElementsByClassName("HeatCell"); for (i=0; i<elements.length; i++) { var data = parseFloat(elements[i].getAttribute("data-heat")); var color = "#00FF00"; if (data <= 1 && data > 0) { color = "hsla(0, 100%, 75%, " + (data) + ")"; } else if (data <= 0 && data >= -1) { color = "hsla(240, 100%, 75%, " + (-data) + ")"; } elements[i].style.backgroundColor = color; } elements = document.getElementById(id).getElementsByClassName("Details"); for (i=0; i<elements.length; i++) { elements[i].setAttribute("data-title", "-"); NetworKit_toggleDetails(elements[i]); elements[i].onclick = function (e) { NetworKit_toggleDetails((e.target) ? e.target : e.srcElement); } } elements = document.getElementById(id).getElementsByClassName("MathValue"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "nan") { elements[i].parentNode.innerHTML = "" } } elements = document.getElementById(id).getElementsByClassName("SubCategory"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "") { elements[i].parentNode.removeChild(elements[i]) } } elements = document.getElementById(id).getElementsByClassName("Category"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "") { elements[i].parentNode.removeChild(elements[i]) } } var isFirefox = false; try { isFirefox = typeof InstallTrigger !== "undefined"; } catch (e) {} if (!isFirefox) { alert("Currently the function\'s output is only fully supported by Firefox."); } } function NetworKit_plotUpdate(source) { var index = source.getAttribute("data-image-index"); var data = source.getAttribute("data-image-" + index); var image = document.getElementById(source.id + "_Image"); image.style.backgroundImage = "url(" + data + ")"; } function NetworKit_showElement(id, show) { var element = document.getElementById(id); element.style.display = (show) ? "block" : "none"; } function NetworKit_overlayShow(source) { NetworKit_overlayUpdate(source); NetworKit_showElement("NetworKit_Overlay", true); } function NetworKit_overlayUpdate(source) { document.getElementById("NetworKit_Overlay_Title").innerHTML = source.title; var index = source.getAttribute("data-image-index"); var data = source.getAttribute("data-image-" + index); var image = document.getElementById("NetworKit_Overlay_Image"); image.setAttribute("data-id", source.id); image.style.backgroundImage = "url(" + data + ")"; var link = document.getElementById("NetworKit_Overlay_Toolbar_Bottom_Save"); link.href = data; link.download = source.title + ".svg"; } function NetworKit_overlayImageShift(delta) { var image = document.getElementById("NetworKit_Overlay_Image"); var source = document.getElementById(image.getAttribute("data-id")); var index = parseInt(source.getAttribute("data-image-index")); var length = parseInt(source.getAttribute("data-image-length")); var index = (index+delta) % length; if (index < 0) { index = length + index; } source.setAttribute("data-image-index", index); NetworKit_overlayUpdate(source); } function NetworKit_toggleDetails(source) { var childs = source.children; var show = false; if (source.getAttribute("data-title") == "-") { ...
# 				element.setAttribute('id', 'NetworKit_script');
# 				document.head.appendChild(element);
# 			}
#
#
# 			{
# 				var element = document.getElementById('NetworKit_style');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('style');
# 				element.type = 'text/css';
# 				element.innerHTML = '.NetworKit_Page { font-family: Arial, Helvetica, sans-serif; font-size: 14px; } .NetworKit_Page .Value:before { font-family: Arial, Helvetica, sans-serif; font-size: 1.05em; content: attr(data-title) ":"; margin-left: -2.5em; padding-right: 0.5em; } .NetworKit_Page .Details .Value:before { display: block; } .NetworKit_Page .Value { font-family: monospace; white-space: pre; padding-left: 2.5em; white-space: -moz-pre-wrap !important; white-space: -pre-wrap; white-space: -o-pre-wrap; white-space: pre-wrap; word-wrap: break-word; tab-size: 4; -moz-tab-size: 4; } .NetworKit_Page .Category { clear: both; padding-left: 1em; margin-bottom: 1.5em; } .NetworKit_Page .Category:before { content: attr(data-title); font-size: 1.75em; display: block; margin-left: -0.8em; margin-bottom: 0.5em; } .NetworKit_Page .SubCategory { margin-bottom: 1.5em; padding-left: 1em; } .NetworKit_Page .SubCategory:before { font-size: 1.6em; display: block; margin-left: -0.8em; margin-bottom: 0.5em; } .NetworKit_Page .SubCategory[data-title]:before { content: attr(data-title); } .NetworKit_Page .Block { display: block; } .NetworKit_Page .Block:after { content: "."; visibility: hidden; display: block; height: 0; clear: both; } .NetworKit_Page .Block .Thumbnail_Overview, .NetworKit_Page .Block .Thumbnail_ScatterPlot { width: 260px; float: left; } .NetworKit_Page .Block .Thumbnail_Overview img, .NetworKit_Page .Block .Thumbnail_ScatterPlot img { width: 260px; } .NetworKit_Page .Block .Thumbnail_Overview:before, .NetworKit_Page .Block .Thumbnail_ScatterPlot:before { display: block; text-align: center; font-weight: bold; } .NetworKit_Page .Block .Thumbnail_Overview:before { content: attr(data-title); } .NetworKit_Page .HeatCell { font-family: "Courier New", Courier, monospace; cursor: pointer; } .NetworKit_Page .HeatCell, .NetworKit_Page .HeatCellName { display: inline; padding: 0.1em; margin-right: 2px; background-color: #FFFFFF } .NetworKit_Page .HeatCellName { margin-left: 0.25em; } .NetworKit_Page .HeatCell:before { content: attr(data-heat); display: inline-block; color: #000000; width: 4em; text-align: center; } .NetworKit_Page .Measure { clear: both; } .NetworKit_Page .Measure .Details { cursor: pointer; } .NetworKit_Page .Measure .Details:before { content: "[" attr(data-title) "]"; display: block; } .NetworKit_Page .Measure .Details .Value { border-left: 1px dotted black; margin-left: 0.4em; padding-left: 3.5em; pointer-events: none; } .NetworKit_Page .Measure .Details .Spacer:before { content: "."; opacity: 0.0; pointer-events: none; } .NetworKit_Page .Measure .Plot { width: 440px; height: 440px; cursor: pointer; float: left; margin-left: -0.9em; margin-right: 20px; } .NetworKit_Page .Measure .Plot .Image { background-repeat: no-repeat; background-position: center center; background-size: contain; height: 100%; pointer-events: none; } .NetworKit_Page .Measure .Stat { width: 500px; float: left; } .NetworKit_Page .Measure .Stat .Group { padding-left: 1.25em; margin-bottom: 0.75em; } .NetworKit_Page .Measure .Stat .Group .Title { font-size: 1.1em; display: block; margin-bottom: 0.3em; margin-left: -0.75em;

# %% [markdown]
# ### Dataset Preparation

# %%
pickle_file_path = 'dataset/amazon_copurchase_graph.pickle'
with open(pickle_file_path, 'rb') as f:
    G = pickle.load(f)

print(G)
# Out:
# DiGraph with 259102 nodes and 1207337 edges

# %% [markdown]
# #### Node Features

# %%
print(f"Total Nodes: {G.number_of_nodes()}")


for node, data in list(G.nodes(data=True))[:5]:
    print(f"Node: {node}, Data: {data}")

print()
sample_node = next(iter(G.nodes(data=True)))[1]
print("Node features:", list(sample_node.keys()))
# Out:
# Total Nodes: 259102
# Node: 1, Data: {'title': 'Patterns of Preaching: A Sermon Sampler', 'group': 'Book', 'salesrank': 396585.0, 'review_cnt': 2, 'downloads': 2, 'rating': 5.0, 'in_degree': 0, 'out_degree': 4, 'pagerank_centrality': 6.210153588242165e-07, 'betweenness_centrality': 0.0, 'harmonic_closeness_centrality': 0.1442557706580312, 'degree_centrality': 1.5437995221940477e-05, 'community': 10}
# Node: 2, Data: {'title': 'Candlemas: Feast of Flames', 'group': 'Book', 'salesrank': 168596.0, 'review_cnt': 12, 'downloads': 12, 'rating': 4.5, 'in_degree': 1, 'out_degree': 4, 'pagerank_centrality': 7.560926314778459e-07, 'betweenness_centrality': 31563.672353370643, 'harmonic_closeness_centrality': 0.1444868764333364, 'degree_centrality': 1.92974940274256e-05, 'community': 10}
# Node: 4, Data: {'title': 'Life Application Bible Commentary: 1 and 2 Timothy and Titus', 'group': 'Book', 'salesrank': 631289.0, 'review_cnt': 1, 'downloads': 1, 'rating': 4.0, 'in_degree': 24, 'out_degree': 5, 'pagerank_centrality': 1.3446471408497216e-05, 'betweenness_centrality': 6528478.270207832, 'harmonic_closeness_centrality': 0.1558843156023248, 'degree_centrality': 0.000111925465359, 'community': 10}
# Node: 5, Data: {'title': 'Prayers That Avail Much for Business: Executive', 'group': 'Book', 'salesrank': 455160.0, 'review_cnt': 0, 'downloads': 0, 'rating': 0.0, 'in_degree': 53, 'out_degree': 5, 'pagerank_centrality': 8.23889149307843e-05, 'betweenness_centrality': 15442396.471775234, 'harmonic_closeness_centrality': 0.1658204661474067, 'degree_centrality': 0.0002238509307181, 'community': 10}
# Node: 15, Data: {'title': 'Wake Up and Smell the Coffee', 'group': 'Book', 'salesrank': 518927.0, 'review_cnt': 8, 'downloads': 8, 'rating': 4.0, 'in_degree': 21, 'out_degree': 5, 'pagerank_centrality': 1.545618113196135e-05, 'betweenness_centrality': 15218614.387948066, 'harmonic_closeness_centrality': 0.1433003301418181, 'degree_centrality': 0.0001003469689426, 'community': 31}
#
# Node features: ['title', 'group', 'salesrank', 'review_cnt', 'downloads', 'rating', 'in_degree', 'out_degree', 'pagerank_centrality', 'betweenness_centrality', 'harmonic_closeness_centrality', 'degree_centrality', 'community']

# %% [markdown]
# Fitur-fitur dari node dalam graph ini meliputi:
#
# *   **`title`**:
#     *   **Tipe Data**: String (Teks)
#     *   **Deskripsi**: Nama atau judul produk. Fitur ini memberikan deskripsi tekstual tentang produk yang dimaksud.
#     *   **Contoh**: "Patterns of Preaching: A Sermon Sampler", "Candlemas: Feast of Flames", dll.
#
# *   **`group`**:
#     *   **Tipe Data**: String (Kategorikal)
#     *   **Deskripsi**: Kategori atau grup tempat produk tersebut berada. Fitur ini membantu dalam memahami jenis produk (misalnya, Buku, Musik, DVD, dll.).
#     *   **Contoh**: "Book"
#
# *   **`salesrank`**:
#     *   **Tipe Data**: Float
#     *   **Deskripsi**: Peringkat penjualan produk di Amazon. Semakin rendah nilai `salesrank`, semakin tinggi tingkat penjualan dan popularitasnya. Fitur ini sering digunakan untuk mengukur seberapa baik suatu produk terjual di Amazon.
#     *   **Contoh**: `396585.0`, `168596.0`, `1270652.0`, dll.
#
# *   **`review_cnt`**:
#     *   **Tipe Data**: Integer
#     *   **Deskripsi**: Jumlah ulasan pelanggan yang diterima oleh produk. Nilai `review_cnt` yang lebih tinggi bisa menunjukkan tingkat visibilitas produk yang lebih besar, popularitas yang lebih tinggi, atau keterlibatan pelanggan yang lebih banyak.
#     *   **Contoh**: `2`, `12`, `1`, `1`, `0`, dll.
#
# *   **`downloads`**:
#     *   **Tipe Data**: Integer
#     *   **Deskripsi**: Jumlah unduhan yang terkait dengan produk. Makna pastinya dapat bervariasi tergantung pada sumber dataset. Bisa saja mewakili unduhan produk digital atau metrik keterlibatan lainnya. Dalam konteks produk "Book" pada contoh ini, bisa merujuk pada unduhan sampel buku atau bentuk keterlibatan lain yang relevan dengan dataset.
#     *   **Contoh**: `2`, `12`, `1`, `1`, `0`, dll.
#
# *   **`rating`**:
#     *   **Tipe Data**: Float
#     *   **Deskripsi**: Rata-rata rating pelanggan terhadap produk, biasanya dalam skala 0 hingga 5 (atau sistem serupa). Fitur ini mencerminkan tingkat kepuasan pelanggan serta persepsi kualitas produk secara keseluruhan.
#     *   **Contoh**: `5.0`, `4.5`, `5.0`, `4.0`, `0.0`, dll.
#
# *   **`in_degree`**:
#     *   **Tipe Data**: Integer
#     *   **Deskripsi**: Jumlah edge (sisi) yang masuk ke node ini. Menunjukkan seberapa banyak produk lain yang terhubung ke produk ini dalam graph. Dalam konteks dataset ini, bisa menunjukkan seberapa sering produk ini direferensikan oleh produk lain.
#     *   **Contoh**: `0`, `1`, `24`, `53`, `21`, dll.
#
# *   **`out_degree`**:
#     *   **Tipe Data**: Integer
#     *   **Deskripsi**: Jumlah edge (sisi) yang keluar dari node ini. Menunjukkan seberapa banyak produk lain yang direferensikan oleh produk ini.
#     *   **Contoh**: `4`, `4`, `5`, `5`, `5`, dll.
#
# *   **`pagerank_centrality`**:
#     *   **Tipe Data**: Float
#     *   **Deskripsi**: Skor PageRank node dalam graph. Metrik ini mengukur kepentingan sebuah node berdasarkan jumlah dan kualitas tautan yang mengarah ke node tersebut. Semakin tinggi nilainya, semakin berpengaruh node tersebut dalam jaringan.
#     *   **Contoh**: `6.21e-07`, `7.56e-07`, `1.34e-05`, dll.
#
# *   **`betweenness_centrality`**:
#     *   **Tipe Data**: Float
#     *   **Deskripsi**: Mengukur seberapa sering sebuah node menjadi perantara dalam jalur terpendek antara dua node lainnya. Node dengan betweenness centrality tinggi berperan sebagai "jembatan" yang menghubungkan berbagai bagian dalam graph.
#     *   **Contoh**: `0.0`, `31563.67`, `6528478.27`, `15442396.47`, dll.
#
# *   **`harmonic_closeness_centrality`**:
#     *   **Tipe Data**: Float
#     *   **Deskripsi**: Versi alternatif dari closeness centrality yang menghitung seberapa dekat suatu node dengan node lain berdasarkan jarak harmonik. Makin tinggi nilainya, makin dekat node tersebut ke banyak node lain dalam graph.
#     *   **Contoh**: `0.1442`, `0.1444`, `0.1558`, `0.1658`, dll.
#
# *   **`degree_centrality`**:
#     *   **Tipe Data**: Float
#     *   **Deskripsi**: Mengukur proporsi node lain yang terhubung dengan node ini dalam graph. Degree centrality dihitung sebagai jumlah total koneksi (degree) node ini dibagi dengan jumlah maksimum koneksi yang mungkin dalam graph.
#     *   **Contoh**: `1.54e-05`, `1.92e-05`, `1.11e-04`, `2.23e-04`, dll.
#
# *   **`community`**:
#     *   **Tipe Data**: Integer (Kategorikal)
#     *   **Deskripsi**: Identitas komunitas tempat node ini tergabung, berdasarkan algoritma deteksi komunitas. Node dalam komunitas yang sama lebih cenderung saling terhubung dibandingkan dengan node di komunitas lain.
#     *   **Contoh**: `10`, `10`, `10`, `31`, dll.

# %% [markdown]
# #### Edge Features

# %%
print(f"Total Edges: {G.number_of_edges()}")

for u, v, data in list(G.edges(data=True))[:5]:
    print(f"Edge: ({u}, {v}), Data: {data}")

sample_edge = next(iter(G.edges(data=True)))[2]
print("\nEdge features:", list(sample_edge.keys()))
# Out:
# Total Edges: 1207337
# Edge: (1, 2), Data: {}
# Edge: (1, 4), Data: {}
# Edge: (1, 5), Data: {}
# Edge: (1, 15), Data: {}
# Edge: (2, 11), Data: {}
#
# Edge features: []

# %% [markdown]
# Tidak ada edge feature pada graph ini

# %% [markdown]
# ### Split Dataset

# %%
nkG = nk.nxadapter.nx2nk(G)

edges = list(G.edges())
existing_edges = set(edges)

# Sampling dengan Networkit Graph (lebih cepat)
def sample_non_edges_nk(nkG, num_samples):
    non_edges = set()
    nodes = list(G.nodes())

    while len(non_edges) < num_samples:
        u, v = random.sample(nodes, 2)
        if not nkG.hasEdge(u, v):
            non_edges.add((u, v))

    return list(non_edges)

num_samples = len(edges)
non_edges = sample_non_edges_nk(nkG, num_samples)

train_edges, test_edges = train_test_split(edges, test_size=0.2, random_state=42)
train_non_edges = random.sample(non_edges, len(train_edges))
test_non_edges = random.sample(non_edges, len(test_edges))

G_train = nx.Graph()
G_train.add_nodes_from(G.nodes())
G_train.add_edges_from(train_edges)

print(f"Train Edges: {len(train_edges)}, Test Edges: {len(test_edges)}")
print(f"Train Non-Edges: {len(train_non_edges)}, Test Non-Edges: {len(test_non_edges)}")
# Out:
# Train Edges: 965869, Test Edges: 241468
# Train Non-Edges: 965869, Test Non-Edges: 241468

# %%
# Metrik evaluasi ranking problem
def precision_at_k(y_true, y_scores, k):
    sorted_indices = np.argsort(y_scores)[::-1]
    top_k = sorted_indices[:k]
    return np.mean(y_true[top_k])

def recall_at_k(y_true, y_scores, k):
    sorted_indices = np.argsort(y_scores)[::-1]
    top_k = sorted_indices[:k]
    return np.sum(y_true[top_k]) / np.sum(y_true)

def mean_average_precision(y_true, y_scores):
    sorted_indices = np.argsort(y_scores)[::-1]
    relevant = np.cumsum(y_true[sorted_indices])
    precision_at_i = relevant / (np.arange(len(y_true)) + 1)
    return np.sum(precision_at_i * y_true[sorted_indices]) / np.sum(y_true)

def f1_beta_at_k(y_true, y_scores, k, beta=1):
    precision_k = precision_at_k(y_true, y_scores, k)
    recall_k = recall_at_k(y_true, y_scores, k)

    if precision_k + recall_k == 0:
        return 0.0

    beta_sq = beta ** 2
    return (1 + beta_sq) * (precision_k * recall_k) / ((beta_sq * precision_k) + recall_k)

# %% [markdown]
# ## Graph Embedding Link Prediction

# %%
train_edges, test_edges = train_test_split(edges, test_size=0.2, random_state=42)
train_edges[:5]
# Out:
# [(168955, 57948),
#  (26010, 27648),
#  (209390, 204186),
#  (123658, 114870),
#  (111403, 49956)]

# %% [markdown]
# Setelah beberapa kali *tuning* dalam parameternya, model yang dibangun adalah sebagai berikut.
#
# - Model TransE dengan embedding berdimensi 200
# - Optimizer Adam dengan learning rate 0.01
# - Loss function: MarginRankingLoss untuk pelatihan
# - Batch size: 256 (pelatihan), 64 (evaluasi)
# - Negative sampling: basic
# - Regularisasi LP dengan bobot 0.01
# - Dilatih selama 20 epoch di GPU
#
# Hanya 40% data yang digunakan untuk menyingkatkan waktu pelatihan. Pembagian dataset pelatihan, pengujian, dan evaluasi adalah 70%, 15%, dan 15%.

# %%
import pandas as pd
import numpy as np
from pykeen.triples import TriplesFactory

# Assuming 'train_edges' and 'G' are defined from the previous code

triples = np.array(edges)
reducer = 0.5

relation_placeholder = np.full((triples.shape[0], 1), "bought_with", dtype=object)
triples = np.column_stack((triples[:, 0], relation_placeholder, triples[:, 1]))
triples = triples.astype(str)

tf = TriplesFactory.from_labeled_triples(triples, create_inverse_triples=True)

tf_train, tf_validation, tf_test, tf_unused = tf.split([0.7 * reducer, 0.15 * reducer, 0.15 * reducer, (1 - reducer)])
# Out:
# WARNING:pykeen.utils:using automatically assigned random_state=207503508
# INFO:pykeen.triples.splitting:done splitting triples to groups of sizes [164222, 90551, 90550, 603669]

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
from pykeen.pipeline import pipeline

# Define and train the model
result = pipeline(
    training=tf_train,
    testing=tf_test,
    validation=tf_validation,
    model='TransE',
    epochs=20,
    model_kwargs={'embedding_dim': 200},
    optimizer='Adam',
    optimizer_kwargs={'lr': 0.01},
    loss='MarginRankingLoss',
    training_kwargs={'batch_size': 256},
    negative_sampler='basic',
    regularizer='LP',
    regularizer_kwargs={'weight': 0.01},
    evaluator_kwargs={
        'filtered': True,
        'batch_size': 64
    },
	device='cuda:0'
)

# Evaluate the model
result.metric_results.to_df()
# Out:
# WARNING:pykeen.pipeline.api:No random seed is specified. Setting to 990906921.
# INFO:pykeen.pipeline.api:Using device: cuda:0
# INFO:pykeen.triples.triples_factory:Creating inverse triples.
# Training epochs on cuda:0:   0%|          | 0/20 [00:00<?, ?epoch/s]
# INFO:pykeen.triples.triples_factory:Creating inverse triples.
# Training batches on cuda:0:   0%|          | 0/3302 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/3302 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/3302 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/3302 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/3302 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/3302 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/3302 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/3302 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/3302 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/3302 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/3302 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/3302 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/3302 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/3302 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/3302 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/3302 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/3302 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/3302 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/3302 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0/3302 [00:00<?, ?batch/s]
# Evaluating on cuda:0:   0%|          | 0.00/90.5k [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 10045.01s seconds
#      Side    Rank_type                      Metric     Value
# 0    head   optimistic  inverse_harmonic_mean_rank  0.000047
# 1    tail   optimistic  inverse_harmonic_mean_rank  0.000041
# 2    both   optimistic  inverse_harmonic_mean_rank  0.000044
# 3    head    realistic  inverse_harmonic_mean_rank  0.000047
# 4    tail    realistic  inverse_harmonic_mean_rank  0.000041
# ..    ...          ...                         ...       ...
# 220  tail    realistic          adjusted_hits_at_k -0.000017
# 221  both    realistic          adjusted_hits_at_k -0.000011
# 222  head  pessimistic          adjusted_hits_at_k -0.000005
# 223  tail  pessimistic          adjusted_hits_at_k -0.000017
# 224  both  pessimistic          adjusted_hits_at_k -0.000011
#
# [225 rows x 4 columns]

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(result.metric_results.to_df())
# Out:
#      Side    Rank_type                               Metric         Value
# 0    head   optimistic           inverse_harmonic_mean_rank  4.709105e-05
# 1    tail   optimistic           inverse_harmonic_mean_rank  4.067223e-05
# 2    both   optimistic           inverse_harmonic_mean_rank  4.388164e-05
# 3    head    realistic           inverse_harmonic_mean_rank  4.709095e-05
# 4    tail    realistic           inverse_harmonic_mean_rank  4.067215e-05
# 5    both    realistic           inverse_harmonic_mean_rank  4.388155e-05
# 6    head  pessimistic           inverse_harmonic_mean_rank  4.709085e-05
# 7    tail  pessimistic           inverse_harmonic_mean_rank  4.067207e-05
# 8    both  pessimistic           inverse_harmonic_mean_rank  4.388146e-05
# 9    head   optimistic                z_geometric_mean_rank -3.570078e+00
# 10   tail   optimistic                z_geometric_mean_rank  1.032088e+01
# 11   both   optimistic                z_geometric_mean_rank  4.887496e+00
# 12   head    realistic                z_geometric_mean_rank -3.570770e+00
# 13   tail    realistic                z_geometric_mean_rank  1.032067e+01
# 14   both    realistic                z_geometric_mean_rank  4.887085e+00
# 15   head  pessimistic                z_geometric_mean_rank -3.570900e+00
# 16   tail  pessimistic                z_geometric_mean_rank  1.031996e+01
# 17   both  pessimistic                z_geometric_mean_rank  4.886265e+00
# 18   head   optimistic                   standard_deviation  7.479108e+04
# 19   tail   optimistic                   standard_deviation  7.583592e+04
# 20   both   optimistic                   standard_deviation  7.532370e+04
# 21   head    realistic                   standard_deviation  7.479108e+04
# 22   tail    realistic                   standard_deviation  7.583593e+04
# 23   both    realistic                   standard_deviation  7.532370e+04
# 24   head  pessimistic                   standard_deviation  7.479108e+04
# 25   tail  pessimistic                   standard_deviation  7.583593e+04
# 26   both  pessimistic                   standard_deviation  7.532370e+04
# 27   head   optimistic  adjusted_inverse_harmonic_mean_rank -3.246095e-06
# 28   tail   optimistic  adjusted_inverse_harmonic_mean_rank -9.664766e-06
# 29   both   optimistic  adjusted_inverse_harmonic_mean_rank -6.455430e-06
# 30   head    realistic  adjusted_inverse_harmonic_mean_rank -3.246188e-06
# 31   tail    realistic  adjusted_inverse_harmonic_mean_rank -9.664844e-06
# 32   both    realistic  adjusted_inverse_harmonic_mean_rank -6.455518e-06
# 33   head  pessimistic  adjusted_inverse_harmonic_mean_rank -3.246293e-06
# 34   tail  pessimistic  adjusted_inverse_harmonic_mean_rank -9.664926e-06
# 35   both  pessimistic  adjusted_inverse_harmonic_mean_rank -6.455610e-06
# 36   head   optimistic         inverse_arithmetic_mean_rank  7.664060e-06
# 37   tail   optimistic         inverse_arithmetic_mean_rank  7.798384e-06
# 38   both   optimistic         inverse_arithmetic_mean_rank  7.730639e-06
# 39   head    realistic         inverse_arithmetic_mean_rank  7.664054e-06
# 40   tail    realistic         inverse_arithmetic_mean_rank  7.798374e-06
# 41   both    realistic         inverse_arithmetic_mean_rank  7.730629e-06
# 42   head  pessimistic         inverse_arithmetic_mean_rank  7.664045e-06
# 43   tail  pessimistic         inverse_arithmetic_mean_rank  7.798365e-06
# 44   both  pessimistic         inverse_arithmetic_mean_rank  7.730622e-06
# 45   head   optimistic               z_arithmetic_mean_rank -3.741476e+00
# 46   tail   optimistic               z_arithmetic_mean_rank  5.305624e+00
# 47   both   optimistic               z_arithmetic_mean_rank  1.106052e+00
# 48   head    realistic               z_arithmetic_mean_rank -3.741960e+00
# 49   tail    realistic               z_arithmetic_mean_rank  5.305027e+00
# 50   both    realistic               z_arithmetic_mean_rank  1.105198e+00
# 51   head  pessimistic               z_arithmetic_mean_rank -3.742524e+00
# 52   tail  pessimistic               z_arithmetic_mean_rank  5.304387e+00
# 53   both  pessimistic               z_arithmetic_mean_rank  1.104436e+00
# 54   head   optimistic        adjusted_arithmetic_mean_rank  1.007179e+00
# 55   tail   optimistic        adjusted_arithmetic_mean_rank  9.898204e-01
# 56   both   optimistic        adjusted_arithmetic_mean_rank  9.984994e-01
# 57   head    realistic        adjusted_arithmetic_mean_rank  1.007179e+00
# 58   tail    realistic        adjusted_arithmetic_mean_rank  9.898216e-01
# 59   both    realistic        adjusted_arithmetic_mean_rank  9.985006e-01
# 60   head  pessimistic        adjusted_arithmetic_mean_rank  1.007181e+00
# 61   tail  pessimistic        adjusted_arithmetic_mean_rank  9.898228e-01
# 62   both  pessimistic        adjusted_arithmetic_mean_rank  9.985016e-01
# 63   head   optimistic                                count  9.055000e+04
# 64   tail   optimistic                                count  9.055000e+04
# 65   both   optimistic                                count  1.811000e+05
# 66   head    realistic                                count  9.055000e+04
# 67   tail    realistic                                count  9.055000e+04
# 68   both    realistic                                count  1.811000e+05
# 69   head  pessimistic                                count  9.055000e+04
# 70   tail  pessimistic                                count  9.055000e+04
# 71   both  pessimistic                                count  1.811000e+05
# 72   head   optimistic          inverse_geometric_mean_rank  1.036803e-05
# 73   tail   optimistic          inverse_geometric_mean_rank  1.086342e-05
# 74   both   optimistic          inverse_geometric_mean_rank  1.061284e-05
# 75   head    realistic          inverse_geometric_mean_rank  1.036801e-05
# 76   tail    realistic          inverse_geometric_mean_rank  1.086341e-05
# 77   both    realistic          inverse_geometric_mean_rank  1.061283e-05
# 78   head  pessimistic          inverse_geometric_mean_rank  1.036800e-05
# 79   tail  pessimistic          inverse_geometric_mean_rank  1.086339e-05
# 80   both  pessimistic          inverse_geometric_mean_rank  1.061281e-05
# 81   head   optimistic         z_inverse_harmonic_mean_rank -3.877287e-01
# 82   tail   optimistic         z_inverse_harmonic_mean_rank -1.154411e+00
# 83   both   optimistic         z_inverse_harmonic_mean_rank -1.090456e+00
# 84   head    realistic         z_inverse_harmonic_mean_rank -3.877399e-01
# 85   tail    realistic         z_inverse_harmonic_mean_rank -1.154420e+00
# 86   both    realistic         z_inverse_harmonic_mean_rank -1.090471e+00
# 87   head  pessimistic         z_inverse_harmonic_mean_rank -3.877524e-01
# 88   tail  pessimistic         z_inverse_harmonic_mean_rank -1.154430e+00
# 89   both  pessimistic         z_inverse_harmonic_mean_rank -1.090486e+00
# 90   head   optimistic                  geometric_mean_rank  9.645032e+04
# 91   tail   optimistic                  geometric_mean_rank  9.205203e+04
# 92   both   optimistic                  geometric_mean_rank  9.422552e+04
# 93   head    realistic                  geometric_mean_rank  9.645054e+04
# 94   tail    realistic                  geometric_mean_rank  9.205210e+04
# 95   both    realistic                  geometric_mean_rank  9.422561e+04
# 96   head  pessimistic                  geometric_mean_rank  9.645058e+04
# 97   tail  pessimistic                  geometric_mean_rank  9.205232e+04
# 98   both  pessimistic                  geometric_mean_rank  9.422579e+04
# 99   head   optimistic  adjusted_arithmetic_mean_rank_index -7.178600e-03
# 100  tail   optimistic  adjusted_arithmetic_mean_rank_index  1.017966e-02
# 101  both   optimistic  adjusted_arithmetic_mean_rank_index  1.500574e-03
# 102  head    realistic  adjusted_arithmetic_mean_rank_index -7.179530e-03
# 103  tail    realistic  adjusted_arithmetic_mean_rank_index  1.017851e-02
# 104  both    realistic  adjusted_arithmetic_mean_rank_index  1.499416e-03
# 105  head  pessimistic  adjusted_arithmetic_mean_rank_index -7.180612e-03
# 106  tail  pessimistic  adjusted_arithmetic_mean_rank_index  1.017729e-02
# 107  both  pessimistic  adjusted_arithmetic_mean_rank_index  1.498381e-03
# 108  head   optimistic                          median_rank  1.308685e+05
# 109  tail   optimistic                          median_rank  1.283590e+05
# 110  both   optimistic                          median_rank  1.296035e+05
# 111  head    realistic                          median_rank  1.308688e+05
# 112  tail    realistic                          median_rank  1.283592e+05
# 113  both    realistic                          median_rank  1.296035e+05
# 114  head  pessimistic                          median_rank  1.308690e+05
# 115  tail  pessimistic                          median_rank  1.283595e+05
# 116  both  pessimistic                          median_rank  1.296040e+05
# 117  head   optimistic                   harmonic_mean_rank  2.123546e+04
# 118  tail   optimistic                   harmonic_mean_rank  2.458680e+04
# 119  both   optimistic                   harmonic_mean_rank  2.278857e+04
# 120  head    realistic                   harmonic_mean_rank  2.123550e+04
# 121  tail    realistic                   harmonic_mean_rank  2.458685e+04
# 122  both    realistic                   harmonic_mean_rank  2.278862e+04
# 123  head  pessimistic                   harmonic_mean_rank  2.123555e+04
# 124  tail  pessimistic                   harmonic_mean_rank  2.458690e+04
# 125  both  pessimistic                   harmonic_mean_rank  2.278867e+04
# 126  head   optimistic            median_absolute_deviation  9.571976e+04
# 127  tail   optimistic            median_absolute_deviation  9.793700e+04
# 128  both   optimistic            median_absolute_deviation  9.678501e+04
# 129  head    realistic            median_absolute_deviation  9.571866e+04
# 130  tail    realistic            median_absolute_deviation  9.793700e+04
# 131  both    realistic            median_absolute_deviation  9.678502e+04
# 132  head  pessimistic            median_absolute_deviation  9.571754e+04
# 133  tail  pessimistic            median_absolute_deviation  9.793700e+04
# 134  both  pessimistic            median_absolute_deviation  9.678501e+04
# 135  head   optimistic                 arithmetic_mean_rank  1.304791e+05
# 136  tail   optimistic                 arithmetic_mean_rank  1.282317e+05
# 137  both   optimistic                 arithmetic_mean_rank  1.293554e+05
# 138  head    realistic                 arithmetic_mean_rank  1.304793e+05
# 139  tail    realistic                 arithmetic_mean_rank  1.282319e+05
# 140  both    realistic                 arithmetic_mean_rank  1.293556e+05
# 141  head  pessimistic                 arithmetic_mean_rank  1.304794e+05
# 142  tail  pessimistic                 arithmetic_mean_rank  1.282320e+05
# 143  both  pessimistic                 arithmetic_mean_rank  1.293557e+05
# 144  head   optimistic                             variance  5.593705e+09
# 145  tail   optimistic                             variance  5.751087e+09
# 146  both   optimistic                             variance  5.673659e+09
# 147  head    realistic                             variance  5.593705e+09
# 148  tail    realistic                             variance  5.751088e+09
# 149  both    realistic                             variance  5.673659e+09
# 150  head  pessimistic                             variance  5.593706e+09
# 151  tail  pessimistic                             variance  5.751088e+09
# 152  both  pessimistic                             variance  5.673660e+09
# 153  head   optimistic   adjusted_geometric_mean_rank_index -1.186108e-02
# 154  tail   optimistic   adjusted_geometric_mean_rank_index  3.429162e-02
# 155  both   optimistic   adjusted_geometric_mean_rank_index  1.148185e-02
# 156  head    realistic   adjusted_geometric_mean_rank_index -1.186338e-02
# 157  tail    realistic   adjusted_geometric_mean_rank_index  3.429090e-02
# 158  both    realistic   adjusted_geometric_mean_rank_index  1.148088e-02
# 159  head  pessimistic   adjusted_geometric_mean_rank_index -1.186381e-02
# 160  tail  pessimistic   adjusted_geometric_mean_rank_index  3.428857e-02
# 161  both  pessimistic   adjusted_geometric_mean_rank_index  1.147896e-02
# 162  head   optimistic                  inverse_median_rank  7.641258e-06
# 163  tail   optimistic                  inverse_median_rank  7.790650e-06
# 164  both   optimistic                  inverse_median_rank  7.715841e-06
# 165  head    realistic                  inverse_median_rank  7.641243e-06
# 166  tail    realistic                  inverse_median_rank  7.790634e-06
# 167  both    realistic                  inverse_median_rank  7.715841e-06
# 168  head  pessimistic                  inverse_median_rank  7.641229e-06
# 169  tail  pessimistic                  inverse_median_rank  7.790619e-06
# 170  both  pessimistic                  inverse_median_rank  7.715811e-06
# 171  head   optimistic                            hits_at_1  0.000000e+00
# 172  tail   optimistic                            hits_at_1  0.000000e+00
# 173  both   optimistic                            hits_at_1  0.000000e+00
# 174  head    realistic                            hits_at_1  0.000000e+00
# 175  tail    realistic                            hits_at_1  0.000000e+00
# 176  both    realistic                            hits_at_1  0.000000e+00
# 177  head  pessimistic                            hits_at_1  0.000000e+00
# 178  tail  pessimistic                            hits_at_1  0.000000e+00
# 179  both  pessimistic                            hits_at_1  0.000000e+00
# 180  head   optimistic                            hits_at_3  1.104362e-05
# 181  tail   optimistic                            hits_at_3  0.000000e+00
# 182  both   optimistic                            hits_at_3  5.521811e-06
# 183  head    realistic                            hits_at_3  1.104362e-05
# 184  tail    realistic                            hits_at_3  0.000000e+00
# 185  both    realistic                            hits_at_3  5.521811e-06
# 186  head  pessimistic                            hits_at_3  1.104362e-05
# 187  tail  pessimistic                            hits_at_3  0.000000e+00
# 188  both  pessimistic                            hits_at_3  5.521811e-06
# 189  head   optimistic                            hits_at_5  1.104362e-05
# 190  tail   optimistic                            hits_at_5  0.000000e+00
# 191  both   optimistic                            hits_at_5  5.521811e-06
# 192  head    realistic                            hits_at_5  1.104362e-05
# 193  tail    realistic                            hits_at_5  0.000000e+00
# 194  both    realistic                            hits_at_5  5.521811e-06
# 195  head  pessimistic                            hits_at_5  1.104362e-05
# 196  tail  pessimistic                            hits_at_5  0.000000e+00
# 197  both  pessimistic                            hits_at_5  5.521811e-06
# 198  head   optimistic                           hits_at_10  3.313087e-05
# 199  tail   optimistic                           hits_at_10  2.208724e-05
# 200  both   optimistic                           hits_at_10  2.760906e-05
# 201  head    realistic                           hits_at_10  3.313087e-05
# 202  tail    realistic                           hits_at_10  2.208724e-05
# 203  both    realistic                           hits_at_10  2.760906e-05
# 204  head  pessimistic                           hits_at_10  3.313087e-05
# 205  tail  pessimistic                           hits_at_10  2.208724e-05
# 206  both  pessimistic                           hits_at_10  2.760906e-05
# 207  head   optimistic                          z_hits_at_k -2.646963e-01
# 208  tail   optimistic                          z_hits_at_k -7.996098e-01
# 209  both   optimistic                          z_hits_at_k -7.525771e-01
# 210  head    realistic                          z_hits_at_k -2.646963e-01
# 211  tail    realistic                          z_hits_at_k -7.996098e-01
# 212  both    realistic                          z_hits_at_k -7.525771e-01
# 213  head  pessimistic                          z_hits_at_k -2.646963e-01
# 214  tail  pessimistic                          z_hits_at_k -7.996098e-01
# 215  both  pessimistic                          z_hits_at_k -7.525771e-01
# 216  head   optimistic                   adjusted_hits_at_k -5.464879e-06
# 217  tail   optimistic                   adjusted_hits_at_k -1.650854e-05
# 218  both   optimistic                   adjusted_hits_at_k -1.098671e-05
# 219  head    realistic                   adjusted_hits_at_k -5.464879e-06
# 220  tail    realistic                   adjusted_hits_at_k -1.650854e-05
# 221  both    realistic                   adjusted_hits_at_k -1.098671e-05
# 222  head  pessimistic                   adjusted_hits_at_k -5.464879e-06
# 223  tail  pessimistic                   adjusted_hits_at_k -1.650854e-05
# 224  both  pessimistic                   adjusted_hits_at_k -1.098671e-05

# %%
model = result

# %%
import numpy as np

metrics = result.metric_results.to_dict()

hmr = model.get_metric('harmonic_mean_rank') # to prioritize top ranking result
ihmr = model.get_metric('inverse_harmonic_mean_rank') # ~= mrr
mrr = model.get_metric('mean_reciprocal_rank')

k = 100000

print("{:<25} {:>10} {:>10} {:>15} {:>15} {:>10} {:>10} {:>10} {:>10} {:>10}".format(
    "Model", "AUC-ROC", "AP Score", f"Precision@100k", f"Recall@100k", "MAP", f"F1@100k", "HMR", "IHMR", "MRR"
))

print("{:<25} {:>10} {:>10} {:>15} {:>15} {:>10} {:>10} {:>10.2f} {:>10.6f} {:>10.2f}".format(
    "TransE (PyKEEN)", "N/A", "N/A", "N/A", "N/A", "N/A", "N/A", hmr, ihmr, mrr
))
# Out:
# Model                        AUC-ROC   AP Score  Precision@100k     Recall@100k        MAP    F1@100k        HMR       IHMR        MRR
# TransE (PyKEEN)                  N/A        N/A             N/A             N/A        N/A        N/A   22788.62   0.000044       0.00

# %%
# Save the model
result.save_to_directory("embedding_model")

# Load the model
# from pykeen.pipeline import PipelineResult
# loaded_result = PipelineResult.from_directory("saved_model")
# trained_model = loaded_result.model
# Out:
# INFO:pykeen.triples.triples_factory:Stored TriplesFactory(num_entities=259102, num_relations=2, create_inverse_triples=True, num_triples=422567) to file:///D:/Academic/Projects/PD/embedding_model2/training_triples
# INFO:pykeen.pipeline.api:Saved to directory: D:\Academic\Projects\PD\embedding_model2
